# %% [markdown]
# # Packages

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Functions and constants

# %%
def Temperatureflux(t,h):
    return t/h

# %%
def CO2flux(co2,h):
    return co2/h

# %%
def Evaportransporation(et,h):
    return et/h

# %% [markdown]
# # Read data

# %%
data = pd.read_csv('Temp.csv')

# %%
h   = data['Hours']
t   = data['Temp']
#et  = data['ET']
#co  = data['CO2']

# %% [markdown]
# # Analysis

# %%
# TTS = Temperatureflux(t,h)

# %% [markdown]
# # Plots

# %%
s1 = plt.plot(h,t)
plt.xlabel('Day (Hrs)')
plt.ylabel('Temperature (K)')
# Out:
# Text(0, 0.5, 'Temperature (K)')
